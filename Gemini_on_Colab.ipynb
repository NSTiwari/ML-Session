# %%
# !pip install -q -U google-generativeai

# %%
from google.colab import userdata
import google.generativeai as genai
from PIL import Image

# %%
API_KEY = userdata.get('gemini')

# Configure the API key.
genai.configure(api_key=API_KEY)

# %%
# List all available models.
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001-tuning

# %% [markdown]
# #### Gemini Pro 1.0 (Text input)

# %%
# Configure the model.
model = genai.GenerativeModel(model_name='gemini-pro')
prompt = "Suggest some best places to visit in India."
# Give the input image and prompt, get response.

response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# **North India:**
#
# * **Taj Mahal, Agra:** One of the Seven Wonders of the World, this iconic mausoleum is a symbol of love and architectural grandeur.
# * **Golden Temple, Amritsar:** The holiest shrine for Sikhs, this magnificent temple welcomes visitors from all faiths.
# * **Varanasi, Ganges River:** A sacred city on the banks of the Ganges River, known for its spiritual significance and ghats where pilgrims bathe.
# * **Himalayas, Uttarakhand:** The abode of the gods, offering breathtaking mountain scenery, trekking trails, and hill stations like Mussoorie and Nainital.
#
# **South India:**
#
# * **Hampi, Karnataka:** The remnants of the once-mighty Vijayanagara Empire, featuring magnificent ruins of temples, palaces, and fortifications.
# * **Meenakshi Amman Temple, Madurai:** A stunning example of Dravidian architecture, dedicated to Lord Shiva and Goddess Meenakshi.
# * **Kerala Backwaters, Alleppey:** A serene retreat with tranquil canals, lush greenery, and traditional houseboats.
# * **Mysore Palace, Karnataka:** The opulent residence of the Wodeyars of Mysore, known for its intricate carvings and grand interiors.
#
# **West India:**
#
# * **Mumbai (Bombay):** India's financial and entertainment hub, offering a vibrant blend of culture, architecture, and nightlife.
# * **Goa:** A former Portuguese colony renowned for its beautiful beaches, churches, and laid-back atmosphere.
# * **Udaipur, Rajasthan:** The "City of Lakes," boasting picturesque palaces, lakes, and gardens.
# * **Jodhpur, Rajasthan:** Known as the "Blue City" due to the distinctive blue-painted houses in its old town.
#
# **East India:**
#
# * **Kolkata (Calcutta):** A cultural and intellectual hub, famous for its Victorian architecture, lively markets, and street food.
# * **Darjeeling, West Bengal:** A hill station in the foothills of the Himalayas, offering stunning views, tea plantations, and a charming toy train ride.
# * **Puri, Odisha:** A coastal city known for its Jagannath Temple, one of the four holiest sites for Hindus.
# * **Kaziranga National Park, Assam:** Home to the world's largest population of one-horned rhinoceroses and a diverse array of wildlife.

# %%
print(response.candidates[0])

# %% [markdown]
# #### Gemini 1.5 Flash (Text + image input)

# %%
# Configure the model.
model = genai.GenerativeModel(model_name='gemini-1.5-flash')

# Load the image.
img = Image.open('/content/image.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
prompt = "Describe this image."

# Give the input image and prompt, get response.
response = model.generate_content([prompt, img], stream=True)
response.resolve()

print(response.text)
# Out:
# The image is a screenshot from the game Grand Theft Auto: Vice City. It depicts a man in a tropical shirt standing in an alleyway with his back to the camera. The man is looking at a white car that is parked behind him. The car's taillights are on and casting a red glow on the ground. In the background, there is a building with a sign that reads "Paradise." There are also some trash bags in the alleyway. The image is set at night and it is raining. The game logo "Grand Theft Auto Vice City" is shown at the top left of the image.
